# %%
# %matplotlib inline

from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3
from keras import applications
from keras.preprocessing import image
from keras.applications.vgg19 import preprocess_input

from scipy import ndimage
from matplotlib.pyplot import imshow
from PIL import Image
from keras.applications.imagenet_utils import decode_predictions
from keras.applications.imagenet_utils import preprocess_input
import numpy as np

# %%
model = VGG16(weights='imagenet', include_top=True)
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
img = Image.open('data/cat1.jpg')
w, h = img.size
s = min(w, h)
y = (h - s) // 2
x = (w - s) // 2
img = img.crop((x, y, s, s))
imshow(np.asarray(img))

# %%
img = img.resize((224, 224), Image.ANTIALIAS)
imshow(np.asarray(img))
# Out:
# C:\Users\Max11mus\AppData\Local\Temp\ipykernel_19180\3995606952.py:1: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((224, 224), Image.ANTIALIAS)

# %%
np_img = np.array(img)
img_batch = np.expand_dims(np_img, axis=0)
pre_processed = preprocess_input(img_batch)
pre_processed.shape
# Out:
# (1, 224, 224, 3)

# %%
features = model.predict(pre_processed)
features.shape
# Out:
# 1/1 [==============================] - 2s 2s/step
# (1, 1000)

# %%
decode_predictions(features, top=5)
# Out:
# [[('n04265275', 'space_heater', 0.1853548),
#   ('n02123159', 'tiger_cat', 0.117584415),
#   ('n02124075', 'Egyptian_cat', 0.06389175),
#   ('n04004767', 'printer', 0.05814121),
#   ('n03642806', 'laptop', 0.045682933)]]

# %%
img = Image.open('data/cat2.jpg')
w, h = img.size
s = min(w, h)
y = (h - s) // 2
x = (w - s) // 2
img = img.crop((x, y, s, s))
imshow(np.asarray(img))

img = img.resize((224, 224), Image.ANTIALIAS)
imshow(np.asarray(img))

np_img = np.array(img)
img_batch = np.expand_dims(np_img, axis=0)
pre_processed = preprocess_input(img_batch)
pre_processed.shape

features = model.predict(pre_processed)
features.shape

decode_predictions(features, top=5)
# Out:
# C:\Users\Max11mus\AppData\Local\Temp\ipykernel_19180\1017764869.py:9: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((224, 224), Image.ANTIALIAS)
# 1/1 [==============================] - 1s 1s/step
# [[('n02123597', 'Siamese_cat', 0.24995397),
#   ('n04265275', 'space_heater', 0.1546431),
#   ('n02441942', 'weasel', 0.053610407),
#   ('n04074963', 'remote_control', 0.036818985),
#   ('n02328150', 'Angora', 0.035866503)]]

# %%
img = Image.open('data/cat3.jpg')
img = img.rotate(90)

w, h = img.size
s = min(w, h)
y = (h - s) // 2
x = (w - s) // 2
img = img.crop((x, y, s, s))
imshow(np.asarray(img))

img = img.resize((224, 224), Image.ANTIALIAS)
imshow(np.asarray(img))

np_img = np.array(img)
img_batch = np.expand_dims(np_img, axis=0)
pre_processed = preprocess_input(img_batch)
pre_processed.shape

features = model.predict(pre_processed)
features.shape

decode_predictions(features, top=5)
# Out:
# C:\Users\Max11mus\AppData\Local\Temp\ipykernel_19180\3311522305.py:11: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((224, 224), Image.ANTIALIAS)
# 1/1 [==============================] - 1s 1s/step
# [[('n02113023', 'Pembroke', 0.107525565),
#   ('n03207941', 'dishwasher', 0.082160704),
#   ('n02123159', 'tiger_cat', 0.06442944),
#   ('n02110806', 'basenji', 0.04480375),
#   ('n04517823', 'vacuum', 0.034878306)]]

# %%
img = Image.open('data/rat1.jpg')
w, h = img.size
s = min(w, h)
y = (h - s) // 2
x = (w - s) // 2
img = img.crop((x, y, s, s))
imshow(np.asarray(img))

img = img.resize((224, 224), Image.ANTIALIAS)
imshow(np.asarray(img))

np_img = np.array(img)
img_batch = np.expand_dims(np_img, axis=0)
pre_processed = preprocess_input(img_batch)
pre_processed.shape

features = model.predict(pre_processed)
features.shape

decode_predictions(features, top=5)
# Out:
# C:\Users\Max11mus\AppData\Local\Temp\ipykernel_19180\706495892.py:9: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((224, 224), Image.ANTIALIAS)
# 1/1 [==============================] - 1s 1s/step
# [[('n02971356', 'carton', 0.40700147),
#   ('n02098286', 'West_Highland_white_terrier', 0.06693309),
#   ('n03482405', 'hamper', 0.06114097),
#   ('n02342885', 'hamster', 0.05821179),
#   ('n02111889', 'Samoyed', 0.05439526)]]

# %%
img = Image.open('data/rat2.jpg')
w, h = img.size
s = min(w, h)
y = (h - s) // 2
x = (w - s) // 2
img = img.crop((x, y, s, s))
imshow(np.asarray(img))

img = img.resize((224, 224), Image.ANTIALIAS)
imshow(np.asarray(img))

np_img = np.array(img)
img_batch = np.expand_dims(np_img, axis=0)
pre_processed = preprocess_input(img_batch)
pre_processed.shape

features = model.predict(pre_processed)
features.shape

decode_predictions(features, top=5)
# Out:
# C:\Users\Max11mus\AppData\Local\Temp\ipykernel_19180\2669845208.py:9: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((224, 224), Image.ANTIALIAS)
# 1/1 [==============================] - 1s 1s/step
# [[('n02971356', 'carton', 0.41733077),
#   ('n03794056', 'mousetrap', 0.05195534),
#   ('n03223299', 'doormat', 0.038847473),
#   ('n03291819', 'envelope', 0.03645412),
#   ('n03642806', 'laptop', 0.032872707)]]

# %%
img = Image.open('data/rat3.jpg')
w, h = img.size
s = min(w, h)
y = (h - s) // 2
x = (w - s) // 2
img = img.crop((x, y, s, s))
imshow(np.asarray(img))

img = img.resize((224, 224), Image.ANTIALIAS)
imshow(np.asarray(img))

np_img = np.array(img)
img_batch = np.expand_dims(np_img, axis=0)
pre_processed = preprocess_input(img_batch)
pre_processed.shape

features = model.predict(pre_processed)
features.shape

decode_predictions(features, top=5)
# Out:
# C:\Users\Max11mus\AppData\Local\Temp\ipykernel_45460\3480807583.py:9: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((224, 224), Image.ANTIALIAS)
# 1/1 [==============================] - 1s 1s/step
# [[('n02443484', 'black-footed_ferret', 0.404192),
#   ('n02441942', 'weasel', 0.1873888),
#   ('n02342885', 'hamster', 0.11341722),
#   ('n03207941', 'dishwasher', 0.051470824),
#   ('n02325366', 'wood_rabbit', 0.051396903)]]
